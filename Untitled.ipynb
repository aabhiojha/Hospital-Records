# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
# %matplotlib inline

# %%
# !pip install plotly plotly --quiet

# %%
sns.set_style('darkgrid')

# %% [markdown]
# ## importing pandas and loading the file

# %%
dataframe = pd.read_csv('medical-charges.csv')

# %%
dataframe.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
dataframe
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
dataframe[['sex','age']]
# Out:
#          sex  age
# 0     female   19
# 1       male   18
# 2       male   28
# 3       male   33
# 4       male   32
# ...      ...  ...
# 1333    male   50
# 1334  female   18
# 1335  female   18
# 1336  female   21
# 1337  female   61
#
# [1338 rows x 2 columns]

# %%
dataframe.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
dataframe['sex'].unique
# Out:
# <bound method Series.unique of 0       female
# 1         male
# 2         male
# 3         male
# 4         male
#          ...
# 1333      male
# 1334    female
# 1335    female
# 1336    female
# 1337    female
# Name: sex, Length: 1338, dtype: object>

# %%
dataframe.shape
# Out:
# (1338, 7)

# %%
maledf = dataframe[dataframe['sex'].isin(['male'])]
maledf
# Out:
#       age   sex     bmi  children smoker     region      charges
# 1      18  male  33.770         1     no  southeast   1725.55230
# 2      28  male  33.000         3     no  southeast   4449.46200
# 3      33  male  22.705         0     no  northwest  21984.47061
# 4      32  male  28.880         0     no  northwest   3866.85520
# 8      37  male  29.830         2     no  northeast   6406.41070
# ...   ...   ...     ...       ...    ...        ...          ...
# 1324   31  male  25.935         1     no  northwest   4239.89265
# 1325   61  male  33.535         0     no  northeast  13143.33665
# 1327   51  male  30.030         1     no  southeast   9377.90470
# 1329   52  male  38.600         2     no  southwest  10325.20600
# 1333   50  male  30.970         3     no  northwest  10600.54830
#
# [676 rows x 7 columns]

# %%
dataframe.iloc[10:100, 0:5]
# Out:
#     age     sex    bmi  children smoker
# 10   25    male  26.22         0     no
# 11   62  female  26.29         0    yes
# 12   23    male  34.40         0     no
# 13   56  female  39.82         0     no
# 14   27    male  42.13         0    yes
# ..  ...     ...    ...       ...    ...
# 95   28  female  37.62         1     no
# 96   54  female  30.80         3     no
# 97   55    male  38.28         0     no
# 98   56    male  19.95         0    yes
# 99   38    male  19.30         0    yes
#
# [90 rows x 5 columns]

# %%
dataframe
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
sns.barplot(data=dataframe,x='age', y='children',hue='sex')
# Out:
# <Axes: xlabel='age', ylabel='children'>

# %%
sns.scatterplot(data=dataframe, x='age', y='children',hue='sex')
# Out:
# <Axes: xlabel='age', ylabel='children'>

# %%
sns.boxplot(data=dataframe, x='charges')
# Out:
# <Axes: xlabel='charges'>

# %%
sns.displot(dataframe, x='charges',kind='kde')
plt.show()

# %%
sns.pairplot(data=dataframe)

# %%
dataframe.age.describe()
# Out:
# count    1338.000000
# mean       39.207025
# std        14.049960
# min        18.000000
# 25%        27.000000
# 50%        39.000000
# 75%        51.000000
# max        64.000000
# Name: age, dtype: float64

# %%
fig = px.histogram(dataframe,
                   x = 'age',
                   marginal = 'box',
                   nbins = 47,
                   title= "Distribution of Age",
                   width=800,
                   height=800
                   )

fig.update_layout(bargap = 0.01)
fig.show()

# %%
px.scatter(dataframe,
           x='charges',
           y='bmi',
           facet_col='sex',
           color='smoker'
           )

# %%
smoker_data = dataframe[dataframe['smoker'] == 'yes']
non_smoker_data = dataframe[dataframe['smoker'] == 'no']
smoker_mean_cost = smoker_data['charges'].mean()
non_smoker_mean_cost = non_smoker_data['charges'].mean()
smoker_mean_cost-non_smoker_mean_cost
# Out:
# np.float64(23615.963533676637)

# %%
fig = px.histogram(dataframe,
                   x='charges',
                   marginal='box',
                   color='smoker',
                   title='Annual Medical Charges',
                   width=800,
                   height=600
                   )
fig.update_layout(bargap=0.01)
fig.show()

# %% [markdown]
# #### Visualize the distribution of medical charges in connection with other factors like 'sex' and 'region'. What do you observe?

# %%
dataframe.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
fig = px.histogram(
    dataframe,
    x='charges',
    color='region',
    marginal='box',
    
    width=800,
    height=500
)
fig.update_layout(bargap=0.1)
fig.show()

# %%
dataframe['smoker'].value_counts()
# Out:
# smoker
# no     1064
# yes     274
# Name: count, dtype: int64

# %%
px.histogram(dataframe, x='smoker', color='sex',title="Smoker")

# %%
yes_smoke_male = dataframe.query('sex=="male" and smoker == "yes"')
yes_smoke_female = dataframe.query('sex=="female" and smoker == "yes"')
yes_smoke_male.shape[0] - yes_smoke_female.shape[0]
# Out:
# 44
